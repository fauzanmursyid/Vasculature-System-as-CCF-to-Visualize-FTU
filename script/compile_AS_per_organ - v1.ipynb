# %% [markdown]
# # Read data

# %%
import pandas as pd

# %%
df_vasculature = pd.read_excel (r'Vasculature Expanded ASCT+B Table.xlsx', sheet_name='DataTable')

# %%
mapping_table = pd.DataFrame(columns=['organ','#AS','#AS present in both table'])

# %% [markdown]
# # 1. Bone Marrow_Blood_v1

# %%
excel = 'ASCT+B_Tables_Standard_Format_3-24-2021.xlsx'
#df_asctb = pd.read_excel (excel, sheet_name=17, header = 10)
organ = 'Bone Marrow_Blood_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
df_asctb.head()
# Out:
#           AS/1   AS/1/LABEL         AS/1/ID cell type general  \
# 0  Bone marrow  Bone marrow  UBERON:0002371         B lineage
# 1        Blood        Blood  UBERON:0000178         B lineage
# 2  Bone marrow  Bone marrow  UBERON:0002371         B lineage
# 3        Blood        Blood  UBERON:0000178         B lineage
# 4  Bone marrow  Bone marrow  UBERON:0002371         B lineage
#
#    cell type general label cell ontology ID  AS/3  AS/3/LABEL  AS/3/ID  \
# 0  lymphocyte of B lineage       CL:0000945   NaN         NaN      NaN
# 1  lymphocyte of B lineage       CL:0000945   NaN         NaN      NaN
# 2  lymphocyte of B lineage       CL:0000945   NaN         NaN      NaN
# 3  lymphocyte of B lineage       CL:0000945   NaN         NaN      NaN
# 4  lymphocyte of B lineage       CL:0000945   NaN         NaN      NaN
#
#                             CT/1  ... BP/12 BP/12/LABEL BP/12/ID FTU  REF/1  \
# 0  precursor B cell (pre B cell)  ...   NaN         NaN      NaN NaN    NaN
# 1                immature B cell  ...   NaN         NaN      NaN NaN    NaN
# 2                immature B cell  ...   NaN         NaN      NaN NaN    NaN
# 3                  memory B cell  ...   NaN         NaN      NaN NaN    NaN
# 4                  memory B cell  ...   NaN         NaN      NaN NaN    NaN
#
#                            REF/1/DOI REF/1/NOTES  REF/2 REF/2/DOI REF/2/NOTES
# 0  DOI: 10.1016/j.exphem.2018.09.004         NaN    NaN       NaN         NaN
# 1      DOI: 10.3389/fimmu.2012.00302         NaN    NaN       NaN         NaN
# 2      DOI: 10.3389/fimmu.2012.00302         NaN    NaN       NaN         NaN
# 3            DOI: 10.1002/jcla.20001         NaN    NaN       NaN         NaN
# 4            DOI: 10.1002/jcla.20001         NaN    NaN       NaN         NaN
#
# [5 rows x 95 columns]

# %%
# Number of unique AS in ASCT+B table
set_AS = set(df_asctb["AS/1/ID"])
unique_AS = len(set_AS)+1
print(set_AS)
print(unique_AS)
# Out:
# {'UBERON:0002371', 'UBERON:0000178'}
# 3

# %%
match = []
for uberon in df_vasculature.UBERON:
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)       
set_match = set(match)    
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Bone Marrow & Blood/Pelvis', unique_AS, match]

# %% [markdown]
# # 2. Brain_v1

# %%
organ = 'Brain_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
#unique_AS = len(df_asctb.drop_duplicates(subset="AS/1/ID")['AS/1/ID'])+len(df_asctb.drop_duplicates(subset="AS/2/ID")['AS/2/ID'])+len(df_asctb.drop_duplicates(subset="AS/3/ID")['AS/3/ID'])+len(df_asctb.drop_duplicates(subset="AS/4/ID")['AS/4/ID'])+len(df_asctb.drop_duplicates(subset="AS/5/ID")['AS/5/ID'])+len(df_asctb.drop_duplicates(subset="AS/6/ID")['AS/6/ID'])+len(df_asctb.drop_duplicates(subset="AS/7/ID")['AS/7/ID'])
#print(unique_AS)
# Number of unique AS in ASCT+B table
set_AS = set(list(df_asctb["AS/1/ID"])+list(df_asctb["AS/2/ID"])+list(df_asctb["AS/3/ID"])+list(df_asctb["AS/4/ID"])+list(df_asctb["AS/5/ID
# %%
match = []
for uberon in df_vasculature.UBERON:
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)   
    
set_match = set(match)    
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Heart', unique_AS, match]

# %% [markdown]
# # 4. Large_Intestine_v1

# %%
organ = 'Large_Intestine_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
set_AS = set(list(df_asctb["AS/1/ID"])+list(df_asctb["AS/2/ID"])+list(df_asctb["AS/3/ID"])+list(df_asctb["AS/4/ID"]))
set_AS = {x for x in set_AS if x==x}
unique_AS = len(set_AS)+1
print(set_AS)
print(unique_AS)
# Out:
# {'UBERON:0003335', 'UBERON:0012489', 'UBERON:0007178', 'UBERON:0012399', 'UBERON_0000423', 'UBERON:0000569', 'UBERON:0002073', 'UBERON:0013485', 'UBERON:0022277', 'UBERON:0007177', 'UBERON:0003342', 'UBERON:0012375', 'UBERON:0022276', 'UBERON:0001159', 'UBERON:0001153', 'UBERON:0001367', 'UBERON:0003331', 'UBERON:0002067', 'UBERON:0002384', 'UBERON:0004928', 'UBERON:0001003', 'UBERON:0000055', 'UBERON:0001157', 'UBERON:0001052', 'UBERON:0012419', 'UBERON:0000059', 'UBERON:0001245', 'UBERON:0002190', 'UBERON:0001961', 'UBERON:0002439', 'UBERON:0001821', 'UBERON:0008974', 'UBERON:0001158', 'UBERON:0012398', 'UBERON:0000397', 'UBERON:0001156', 'UBERON:0000317', 'UBERON:0012498', 'UBERON:0001962', 'UBERON:0004760', 'UBERON:0004989', 'UBERON:0011184', 'UBERON:0015716', 'UBERON:0005304', 'UBERON:0005742', 'UBERON:0001154', 'UBERON:0000159', 'UBERON:0006134'}
# 49

# %%
match = []
for uberon in df_vasculature.UBERON:
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)    
set_match = set(match)
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Intestine, Large', unique_AS, match]

# %%
mapping_table
# Out:
#                         organ #AS #AS present in both table
# 0  Bone Marrow & Blood/Pelvis   3                         0
# 1                       Brain  66                         0
# 2                       Heart  50                         9
# 3            Intestine, Large  49                         0

# %% [markdown]
# # 5. Kidney_v1

# %%
organ = 'Kidney_v1'
df_asctb = pd.read_csv('ASCT-B_VH_Kidney.csv', header = 10)
#df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
set_AS = set(list(df_asctb["AS/1/ID"])+list(df_asctb["AS/2/ID"])+list(df_asctb["AS/3/ID"])+list(df_asctb["AS/4/ID"])+list(df_asctb["AS/5/ID"]))
set_AS = {x for x in set_AS if x==x}
unique_AS = len(set_AS)+1
print(set_AS)
print(unique_AS)
# Out:
# {'UBERON:0001291', 'UBERON:0001224', 'UBERON:0004190', 'UBERON:0001294', 'UBERON:0005215', 'UBERON:0004204', 'UBERON:0005272', 'UBERON:0005096', 'UBERON:0008716', 'UBERON:0001231', 'UBERON:0002042', 'UBERON:0001227', 'UBERON:0004193', 'UBERON:0004294', 'UBERON:0001232', 'UBERON:0001986', 'UBERON:0009095', 'UBERON:0014464', 'UBERON:0005271', 'UBERON:0001289', 'UBERON:0001229', 'UBERON:0000362', 'UBERON:0001228', 'UBERON:0001292', 'UBERON:0002113', 'UBERON:0002015', 'UBERON:0004196', 'UBERON:0009202', 'UBERON:0001225', 'UBERON:0006544', 'UBERON:0004639', 'UBERON:0005097', 'UBERON:0006517', 'UBERON:0009091', 'UBERON:0004100', 'UBERON:0012441', 'UBERON:0002320', 'UBERON:0004201', 'UBERON:0004202', 'UBERON:0002319', 'UBERON:0001226', 'UBERON:0009883', 'UBERON:0004197', 'UBERON:0004203', 'UBERON:0004200', 'UBERON:0004188', 'UBERON:0004134', 'UBERON:0004205', 'UBERON:0001285', 'UBERON:0005750', 'UBERON:0004640', 'UBERON:0002189', 'UBERON:0006852', 'UBERON:0001284'}
# 55

# %%
match = []
for uberon in df_vasculature.UBERON:
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)  
    
set_match = set(match)    
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Kidney', unique_AS, match]

# %% [markdown]
# # 6. Lung_v1

# %%
organ = 'Lung_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
set_AS = list(df_asctb["AS/1/ID"])+list(df_asctb["AS/2/ID"])+list(df_asctb["AS/3/ID"])+list(df_asctb["AS/4/ID"])+list(df_asctb["AS/5/ID"])+list(df_asctb["AS/6/ID"])+list(df_asctb["AS/7/ID"])+list(df_asctb["AS/8/ID"])+list(df_asctb["AS/9/ID"])
set_AS = {x for x in set_AS if x==x}
unique_AS = len(set_AS)+1
print(set_AS)
print(unique_AS)
# Out:
# {
# %%
match = []
for uberon in df_vasculature.UBERON:
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)
    
set_match = set(match)    
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Lymph Node', unique_AS, match]

# %%
mapping_table
# Out:
#                         organ  #AS #AS present in both table
# 0  Bone Marrow & Blood/Pelvis    3                         0
# 1                       Brain   66                         0
# 2                       Heart   50                         9
# 3            Intestine, Large   49                         0
# 4                      Kidney   55                         3
# 5                        Lung  140                         4
# 6                  Lymph Node   21                         0

# %% [markdown]
# # 8. Skin_v1

# %%
organ = 'Skin_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
set_AS = list(df_asctb["AS/1/ID"])+list(df_asctb["AS/2/ID"])+list(df_asctb["AS/3/ID"])+list(df_asctb["AS/4/ID"])
set_AS = {x for x in set_AS if x==x}
unique_AS = len(set_AS)+1
print(set_AS)
print(unique_AS)
# Out:
# {'UBERON_0001003', 'UBERON_0001821', 'UBERON:0007121', 'UBERON_0002072', 'UBERON_0002027', 'UBERON:0002097', 'UBERON_0000423', 'UBERON_0008974', 'UBERON_0008198', 'UBERON_0002069', 'UBERON_0002073', 'UBERON:0035549', 'UBERON_0002199', 'UBERON_0002026', 'UBERON_0002025'}
# 16

# %%
match = []
for uberon in df_vasculature.UBERON:
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)    
set_match = set(match)    
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Skin', unique_AS, match]

# %% [markdown]
# # 9. Spleen_v1

# %%
organ = 'Spleen_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
set_AS = list(df_asctb["AS/1/ID"])+list(df_asctb["AS/2/ID"])+list(df_asctb["AS/3/ID"])+list(df_asctb["AS/4/ID"])+list(df_asctb["AS/5/ID"])+list(df_asctb["A S/6/ID"])
set_AS = {x for x in set_AS if x==x}
unique_AS = len(set_AS)+1
print(set_AS)
print(unique_AS)
# Out:
# {'UBERON:0001638', 'UBERON:0001251', 'UBERON:0010400', 'UBERON:1000023', 'UBERON:0001194', 'UBERON:0001250', 'UBERON:0001266', 'UBERON:0010421', 'UBERON:0001959', 'UBERON:0004042', 'UBERON:0001248', 'UBERON:0010399', 'UBERON:0002106', 'UBERON:0004641', 'UBERON:0005353', 'UBERON:0002108', 'UBERON:0001960', 'UBERON:0010401', 'UBERON:0001265', 'UBERON:0013132', 'UBERON:0001473', 'UBERON:0003713', 'UBERON:0002107', 'UBERON:0009967', 'UBERON:0005196', 'NOT FOUND'}
# 27

# %%
match = []
for uberon in df_vasculature.UBERON:
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)
    
set_match = set(match)    
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Spleen', unique_AS, match]

# %% [markdown]
# # 10. Thymus_v1

# %%
organ = 'Thymus_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
set_AS = list(df_asctb["AS/1/ID"])+list(df_asctb["AS/2/ID"])+list(df_asctb["AS/3/ID"])+list(df_asctb["AS/4/ID"])+list(df_asctb["AS/5/ID"])
set_AS = {x for x in set_AS if x==x}
unique_AS = len(set_AS)+1
print(set_AS)
print(unique_AS)
# Out:
# {'UBERON:0004791', 'UBERON:0001013', 'UBERON:0010397', 'UBERON:0001591', 'UBERON:0002384', 'UBERON:0002124', 'UBERON:0003846', 'UBERON:0018243', 'UBERON:0002370', 'UBERON:0002125', 'UBERON:0006936', 'UBERON:0003483', 'UBERON:0002123', 'UBERON:0001021', 'UBERON:0005483'}
# 16

# %%
match = []
for uberon in df_vasculature.UBERON:    
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)
    
set_match = set(match)    
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Thymus', unique_AS, match]

# %% [markdown]
# # 11. Vasculature_v1

# %%
organ = 'Vasculature_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %%
set_AS = list(df_asctb["AS/1/ID"])+list(df_asctb["AS/2/ID"])+list(df_asctb["AS/3/ID"])+list(df_asctb["AS/4/ID"])+list(df_asctb["AS/5/ID"])+list(df_asctb["AS/6/ID"])+list(df_asctb["AS/7/ID"])+list(df_asctb["AS/8/ID"])+list(df_asctb["AS/9/ID"])+list(df_asctb["AS/10/ID"])+list(df_asctb["AS/11/ID"])+list(df_asctb["AS/12/ID"])+list(df_asctb["AS/13/ID"])+list(df_asctb["AS/14/ID"])+list(df_asctb["AS/15/ID"])+list(df_asctb["AS/16/ID"])+list(df_asctb["AS/17/ID"])+list(df_asctb["AS/18/ID"])+list(df_asctb["AS/19/ID"])
set_AS = {x for x in set_AS if x==x}
 'fma50836', 'fma22911', 'UBERON:0001194', 'UBERON:0001313', 'fma4739', 'fma61437', 'UBERON:0001652', 'fma49602', 'fma4498', 'fma8639', 'fma8617', 'UBERON:0002080', 'UBERON:0007146', 'UBERON:0009040', 'fma0329301', 'UBERON:0001140', 'fma22584', 'UBERON:0001626', 'UBERON:0001552', 'fma15395', 'fma44356', 'UBERON:0005475', 'UBERON:0001397', 'UBERON:0001196', 'fma49831', 'fma4735', 'fma4245', 'fma6646', 'UBERON:0005628', 'UBERON:0001355', 'fma22684', 'fma14755', 'UBERON:0001516', 'UBERON:0012318', 'UBERON:0006663', 'fma8632', 'UBERON:0001070', 'UBERON:0003468', 'fma51238', 'UBERON:0035532', 'fma14782', 'fma13279', 'fma44650', 'UBERON:0001189', 'fma4147', 'fma21121', 'fma49483', 'fma14746', 'fma4184', 'fma79658', 'fma44034', 'fma68193', 'UBERON:0010132', 'UBERON:0001187', 'fma70501', 'UBERON:0008889', 'UBERON:0001669', 'fma4879', 'fma14835', 'UBERON:0001614', 'UBERON:0001561', 'UBERON:0035225', 'UBERON:0014694', 'fma322921', 'fma14762', 'fma67977', 'UBERON:0001217', 'UBERON:0001314', 'fma4314', 'fma4990', 'UBERON:0012255', 'fma20805', 'fma70893', 'UBERON:0001634', 'UBERON:0001655', 'fma20853', 'UBERON:0005431', 'UBERON:0035829', 'UBERON:0018252', 'UBERON:0001394', 'fma8619', 'fma50830', 'UBERON:0012187', 'fma44649', 'fma20886', 'UBERON:0018253', 'fma50910', 'fma3840', 'UBERON:0035042', 'fma4452', 'UBERON:0001312', 'UBERON:0014691', 'fma22506', 'fma70479', 'fma20701', 'UBERON:0001142', 'fma50771', 'UBERON:0001620', 'UBERON:0001340', 'fma49561', 'UBERON:0002505', 'UBERON:0005168', ' ...
# 754

# %%
match = []
for uberon in df_vasculature.UBERON:
    for asid in set_AS:
        if uberon == asid:
            match.append(uberon)
    
set_match = set(match)    
match = len(set_match)

# %%
mapping_table.loc[len(mapping_table.index)] = ['Vasculature', unique_AS, match]

# %%
mapping_table
# Out:
#                          organ  #AS #AS present in both table
# 0   Bone Marrow & Blood/Pelvis    3                         0
# 1                        Brain   66                         0
# 2                        Heart   50                         9
# 3             Intestine, Large   49                         0
# 4                       Kidney   55                         3
# 5                         Lung  140                         4
# 6                   Lymph Node   21                         0
# 7                         Skin   16                         0
# 8                       Spleen   27                         6
# 9                       Thymus   22                         0
# 10                 Vasculature  754                       362

# %%
unique_AS = len(df_asctb.drop_duplicates(subset="AS/1/ID")['AS/1/ID'])+len(df_asctb.drop_duplicates(subset="AS/2/ID")['AS/2/ID'])+len(df_asctb.drop_duplicates(subset="AS/3/ID")['AS/3/ID'])+len(df_asctb.drop_duplicates(subset="AS/4/ID")['AS/4/ID'])+len(df_asctb.drop_duplicates(subset="AS/5/ID")['AS/5/ID'])+len(df_asctb.drop_duplicates(subset="AS/6/ID")['AS/6/ID'])+len(df_asctb.drop_duplicates(subset="AS/7/ID")['AS/7/ID'])+len(df_asctb.drop_duplicates(subset="AS/8/ID")['AS/8/ID'])+len(df_asctb.drop_duplicates(subset="AS/9/ID")['AS/9/ID'])+len(df_asctb.drop_duplicates(subset="AS/10/ID")['AS/10/ID'])+len(df_asctb.drop_duplicates(subset="AS/11/ID")['AS/11/ID'])+len(df_asctb.drop_duplicates(subset="AS/12/ID")['AS/12/ID'])+len(df_asctb.drop_duplicates(subset="AS/13/ID")['AS/13/ID'])+len(df_asctb.drop_duplicates(subset="AS/14/ID")['AS/14/ID'])+len(df_asctb.drop_duplicates(subset="AS/15/ID")['AS/15/ID'])+len(df_asctb.drop_duplicates(subset="AS/16/ID")['AS/16/ID'])+len(df_asctb.drop_duplicates(subset="AS/17/ID")['AS/17/ID'])+len(df_asctb.drop_duplicates(subset="AS/18/ID")['AS/18/ID'])+len(df_asctb.drop_duplicates(subset="AS/19/ID")['AS/19/ID'])
print(unique_AS)

# %%
heart = df[df.BodyPart == 'heart'].shape[0] + df[df.BodyPart == 'heart chamber'].shape[0]
 = df[df.BodyPart == 'heart'].shape[0] + df[df.BodyPart == 'heart chamber'].shape[0]
# Out:
#   File "<ipython-input-54-788e20192699>", line 2
#     = df[df.BodyPart == 'heart'].shape[0] + df[df.BodyPart == 'heart chamber'].shape[0]
#     ^
# IndentationError: unexpected indent

# %%
for i in range(0,len(df_asctb)+1):
    if df_asctb['AS/1'][0] |
# Out:
# range(0, 868)

# %%
for i in range (0,len(df_asctb)+1):
    if (len(df_asctb['AS/1'][0]) > 0)  & (len(df_asctb['AS/1/ID'][0]) == 0):
        print(i)
# Out:
# True

# %%
import math
df_asctb['AS/4'][0].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-307-2f8c8e1e1733> in <module>
#       1 import math
# ----> 2 df_asctb['AS/4'][0].isnull()
#
# AttributeError: 'float' object has no attribute 'isnull'

# %%
  df_asctb.head()
# Out:
#           AS/1   AS/1/LABEL         AS/1/ID         AS/2           AS/2/LABEL  \
# 0  vasculature  vasculature  UBERON:0002049  left atrium  left cardiac atrium
# 1  vasculature  vasculature  UBERON:0002049  left atrium  left cardiac atrium
# 2  vasculature  vasculature  UBERON:0002049  left atrium  left cardiac atrium
# 3  vasculature  vasculature  UBERON:0002049  left atrium  left cardiac atrium
# 4  vasculature  vasculature  UBERON:0002049  left atrium  left cardiac atrium
#
#           AS/2/ID                           AS/3  \
# 0  UBERON:0002079                            NaN
# 1  UBERON:0002079   left inferior pulmonary vein
# 2  UBERON:0002079   left superior pulmonary vein
# 3  UBERON:0002079  right inferior pulmonary vein
# 4  UBERON:0002079  right superior pulmonary vein
#
#                       AS/3/LABEL   AS/3/ID AS/4  ...  \
# 0                            NaN       NaN  NaN  ...
# 1   Left inferior pulmonary vein  fma49913  NaN  ...
# 2   Left superior pulmonary vein  fma49916  NaN  ...
# 3  Right inferior pulmonary vein  fma49911  NaN  ...
# 4  Right superior pulmonary vein  fma49914  NaN  ...
#
#                             CT/1                     CT/1/LABEL     CT/1/ID  \
# 0       cardiac endothelial cell       cardiac endothelial cell  CL:0010008
# 1  blood vessel endothelial cell  blood vessel endothelial cell  CL:0000071
# 2  blood vessel endothelial cell  blood vessel endothelial cell  CL:0000071
# 3  blood vessel endothelial cell  blood vessel endothelial cell  CL:0000071
# 4  blood vessel endothelial cell  blood vessel endothelial cell  CL:0000071
#
#             BG/1 BG/1/LABEL    BG/1/ID FTU  \
# 0  PECAM1 (CD31)     PECAM1  HGNC:8823 NaN
# 1  PECAM1 (CD31)     PECAM1  HGNC:8823 NaN
# 2  PECAM1 (CD31)     PECAM1  HGNC:8823 NaN
# 3  PECAM1 (CD31)     PECAM1  HGNC:8823 NaN
# 4  PECAM1 (CD31)     PECAM1  HGNC:8823 NaN
#
#                                           REF/1 REF/1/DOI REF/1/NOTES
# 0           https://en.wikipedia.org/wiki/Heart       NaN         NaN
# 1  https://en.wikipedia.org/wiki/Pulmonary_vein       NaN         NaN
# 2  https://en.wikipedia.org/wiki/Pulmonary_vein       NaN         NaN
# 3  https://en.wikipedia.org/wiki/Pulmonary_vein       NaN         NaN
# 4  https://en.wikipedia.org/wiki/Pulmonary_vein       NaN         NaN
#
# [5 rows x 67 columns]

# %%
set_AS = list(set(df_asctb["AS/1"]))+list(set(df_asctb["AS/2"]))+list(set(df_asctb["AS/3"]))+list(set(df_asctb["AS/4"]))+list(set(df_asctb["AS/5"]))+list(set(df_asctb["AS/6"]))+list(df_asctb["AS/7"])+list(df_asctb["AS/8"])+list(df_asctb["AS/9"])+list(df_asctb["AS/10"])+list(df_asctb["AS/11"])+list(df_asctb["AS/12"])+list(df_asctb["AS/13"])+list(df_asctb["AS/14"])+list(df_asctb["AS/15"])+list(df_asctb["AS/16"])+list(df_asctb["AS/17"])+list(df_asctb["AS/18"])+list(df_asctb["AS/19"])
set_AS = {x for x in set_AS if x==x}

#set_AS = list(set(df_asctb["AS/1"])) + list(set(df_asctb["AS/2"])) + list(set(df_asctb["AS/3"])) + list(set(df_asctb["AS/4"])) + list(set(df_asctb["AS/5"])) + list(set(df_asctb["AS/6"])) + list(set(df_asctb["AS/7"])) + list(set(df_asctb["AS/8"])) + list(set(df_asctb["AS/9"]))
#set_AS
#set_AS = set().union(*set_AS)
#set_AS = [x for x in set_AS if x==x]
unique_AS = len(set_AS)+1
print(unique_AS)

for i in set_AS:
    print(i)
# Out:
# 870
# inferior laryngeal vein
# superior cerebellar artery
# left posterior intercostal vein 5
# tentorial artery
# descending genicular artery
# left posterior intercostal vein 4
# inferior mesenteric vein
# superior sagittal sinus
# deep dorsal vein of clitoris
# right middle suprarenal artery
# deferent duct artery
# supreme intercostal artery
# inferior epigastric vein
# musculophrenic vein
# left first superior phrenic artery
# superior rectal artery
# communicating branch of fibular artery
# superior thoracic artery
# median sacral vein
# superficial temporal artery
# great cerebral vein
# lacrimal artery
# posterior accessory saphenous vein
# middle colic vein
# posterior radicular artery
# anterior intercostal artery 6
# ileal vein
# perforating artery
# superior left bronchial artery
# pericallosal artery
# central retinal vein
# axillary vein
# radial artery of uterus
# renal afferent arteriole
# cremasteric artery
# acetabular branch of obturator artery
# posterior communicating artery
# inferior pharyngeal artery
# sinoatrial nodal artery
