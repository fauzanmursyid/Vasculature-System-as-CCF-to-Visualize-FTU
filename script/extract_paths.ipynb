# %%
import pandas as pd
df_vasculature = pd.read_excel (r'Vasculature Expanded ASCT+B Table.xlsx', sheet_name='DataTable')

# %%
excel = 'ASCT+B_Tables_Standard_Format_3-24-2021.xlsx'
organ = 'Large_Intestine_v1'
df_asctb = pd.read_excel (excel, sheet_name=organ, header = 10)

# %% [markdown]
# # 1. Colonic Crypts

# %%
for i in df_vasculature.index:
    if df_asctb['AS/4/ID'][i] == "UBERON:0011184":
        print(df_asctb['AS/2/LABEL'][i] + '' + df_asctb['AS/3/LABEL'][i])
# Out:
# ileocecal valvemucosa of appendix
# ileocecal valvemucosa of appendix
# ileocecal valvemucosa of appendix
# ileocecal valvemucosa of appendix
# ileocecal valvemucosa of appendix
# ileocecal valvemucosa of appendix
# ileocecal valvemucosa of appendix
# cecummucosa of appendix
# cecummucosa of appendix
# cecummucosa of appendix
# cecummucosa of appendix
# cecummucosa of appendix
# cecummucosa of appendix
# cecummucosa of appendix
# vermiform appendixmucosa of appendix
# vermiform appendixmucosa of appendix
# vermiform appendixmucosa of appendix
# vermiform appendixmucosa of appendix
# vermiform appendixmucosa of appendix
# vermiform appendixmucosa of appendix
# vermiform appendixmucosa of appendix
# ascending colonmucosa
# ascending colonmucosa
# ascending colonmucosa
# ascending colonmucosa
# ascending colonmucosa
# ascending colonmucosa
# ascending colonmucosa
# hepatic flexure of colonmucosa
# hepatic flexure of colonmucosa
# hepatic flexure of colonmucosa
# ...

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] == "short branch of vasa recta of colon":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)
# Out:
# ['left ventricle', 'aorta', 'ascending aorta', 'aortic arch', 'descending aorta', 'descending thoracic aorta', 'abdominal aorta', 'inferior mesenteric artery', 'left colic artery', 'ascending branch of left colic artery', 'marginal artery of Drummond', 'vasa recta of colon', 'short branch of vasa recta of colon']

# %%
#colnames = df_vasculature.columns.values.tolist()
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()
# Out:
# Empty DataFrame
# Columns: [BranchesFrom, Vessel, VesselType, BodyPart, Sex, Anastomoses, ForBranchesSee, MergedVessel, CoordX, CoordY, BranchSequence, CellType, CellTypeLabel, CellTypeID, Biomarkers, BiomarkersLabel, BiomarkersID, ReferenceURL, Reference, ReferenceDOI, UBERON, FMA, BodyPartUberon, UBERONLabel, FMALabel, PathFromHeart, BothTable]
# Index: []
#
# [0 rows x 27 columns]

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)
# Out:
#                              BranchesFrom  \
# 0                          left ventricle
# 1                          left ventricle
# 2                                   aorta
# 3                         ascending aorta
# 4                             aortic arch
# 5                        descending aorta
# 6               descending thoracic aorta
# 7                         abdominal aorta
# 8              inferior mesenteric artery
# 9                       left colic artery
# 10  ascending branch of left colic artery
# 11            marginal artery of Drummond
# 12                    vasa recta of colon
#
#                                    Vessel     VesselType  \
# 0                          left ventricle  heart chamber
# 1                                   aorta         artery
# 2                         ascending aorta         artery
# 3                             aortic arch         artery
# 4                        descending aorta         artery
# ...

# %%
node_edge.head()
# Out:
#       BranchesFrom            Vessel     VesselType  \
# 0   left ventricle    left ventricle  heart chamber
# 1   left ventricle             aorta         artery
# 2            aorta   ascending aorta         artery
# 3  ascending aorta       aortic arch         artery
# 4      aortic arch  descending aorta         artery
#
#                            BodyPart  Sex Anastomoses  ForBranchesSee  \
# 0                     heart chamber  NaN         NaN             NaN
# 1  abdominal cavity;thoracic cavity  NaN         NaN             NaN
# 2                   thoracic cavity  NaN         NaN             NaN
# 3                   thoracic cavity  NaN         NaN             NaN
# 4                   thoracic cavity  NaN         NaN             NaN
#
#   MergedVessel  CoordX  CoordY  ...  \
# 0            0    10.0   -10.0  ...
# 1            0    15.0    30.0  ...
# 2            0    20.0    40.0  ...
# 3            0    30.0    50.0  ...
# 4            0    40.0    40.0  ...
#
# ...

# %%
df_matching = pd.read_csv('AS_matching_all.csv')

# %%
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                              BranchesFrom  \
# 0                          left ventricle
# 1                          left ventricle
# 2                                   aorta
# 3                         ascending aorta
# 4                             aortic arch
# 5                        descending aorta
# 6               descending thoracic aorta
# 7                         abdominal aorta
# ...

# %%
node_edge.to_csv('intestine_large-crypts.vasculature_network.csv')

# %% [markdown]
# # 2. Alveoli

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] == "subsegmental pulmonary artery":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)
# Out:
# ['right ventricle', 'pulmonary trunk', 'left pulmonary artery', 'segmental pulmonary artery', 'subsegmental pulmonary artery']

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()
# Out:
# Empty DataFrame
# Columns: [BranchesFrom, Vessel, VesselType, BodyPart, Sex, Anastomoses, ForBranchesSee, MergedVessel, CoordX, CoordY, BranchSequence, CellType, CellTypeLabel, CellTypeID, Biomarkers, BiomarkersLabel, BiomarkersID, ReferenceURL, Reference, ReferenceDOI, UBERON, FMA, BodyPartUberon, UBERONLabel, FMALabel, PathFromHeart, BothTable]
# Index: []
#
# [0 rows x 27 columns]

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)
# Out:
#                  BranchesFrom                         Vessel     VesselType  \
# 0             right ventricle                right ventricle  heart chamber
# 1             right ventricle                pulmonary trunk         artery
# 2             pulmonary trunk          left pulmonary artery         artery
# 3       left pulmonary artery     segmental pulmonary artery         artery
# 4  segmental pulmonary artery  subsegmental pulmonary artery         artery
#
#         BodyPart  Sex  Anastomoses  ForBranchesSee MergedVessel  CoordX  \
# 0  heart chamber  NaN          NaN             NaN            0   -10.0
# 1           lung  NaN          NaN             NaN            0     0.0
# 2           lung  NaN          NaN             NaN            0    10.0
# 3           lung  NaN          NaN             NaN            1     NaN
# 4           lung  NaN          NaN             NaN            0     NaN
#
#    CoordY  ...                                       ReferenceURL  \
# ...

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)
# Out:
#                  BranchesFrom                         Vessel     VesselType  \
# 0             right ventricle                right ventricle  heart chamber
# 1             right ventricle                pulmonary trunk         artery
# 2             pulmonary trunk          left pulmonary artery         artery
# 3       left pulmonary artery     segmental pulmonary artery         artery
# 4  segmental pulmonary artery  subsegmental pulmonary artery         artery
#
#         BodyPart  Sex  Anastomoses  ForBranchesSee MergedVessel  CoordX  \
# 0  heart chamber  NaN          NaN             NaN            0   -10.0
# 1           lung  NaN          NaN             NaN            0     0.0
# 2           lung  NaN          NaN             NaN            0    10.0
# 3           lung  NaN          NaN             NaN            1     NaN
# 4           lung  NaN          NaN             NaN            0     NaN
#
#    CoordY  ...                                       ReferenceURL  \
# ...

# %%
node_edge.to_csv('lung-alveoli.network_graph.csv')

# %% [markdown]
# # 3. Liver's Lobule

# %%
for i in df_vasculature.index:
    if df_vasculature['UBERON'][i] == "UBERON:0015482":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)
# Out:
# ['left ventricle', 'aorta', 'ascending aorta', 'aortic arch', 'descending aorta', 'descending thoracic aorta', 'abdominal aorta', 'celiac artery', 'common hepatic artery', 'proper hepatic artery', 'right hepatic artery']

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()
# Out:
# Empty DataFrame
# Columns: [BranchesFrom, Vessel, VesselType, BodyPart, Sex, Anastomoses, ForBranchesSee, MergedVessel, CoordX, CoordY, BranchSequence, CellType, CellTypeLabel, CellTypeID, Biomarkers, BiomarkersLabel, BiomarkersID, ReferenceURL, Reference, ReferenceDOI, UBERON, FMA, BodyPartUberon, UBERONLabel, FMALabel, PathFromHeart, BothTable]
# Index: []
#
# [0 rows x 27 columns]

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)
# Out:
#                  BranchesFrom                     Vessel     VesselType  \
# 0              left ventricle             left ventricle  heart chamber
# 1              left ventricle                      aorta         artery
# 2                       aorta            ascending aorta         artery
# 3             ascending aorta                aortic arch         artery
# 4                 aortic arch           descending aorta         artery
# 5            descending aorta  descending thoracic aorta         artery
# 6   descending thoracic aorta            abdominal aorta         artery
# 7             abdominal aorta              celiac artery         artery
# 8               celiac artery      common hepatic artery         artery
# 9       common hepatic artery      proper hepatic artery         artery
# 10      proper hepatic artery       right hepatic artery         artery
#
#                             BodyPart  Sex  Anastomoses  ForBranchesSee  \
# ...

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  BranchesFrom                     Vessel     VesselType  \
# 0              left ventricle             left ventricle  heart chamber
# 1              left ventricle                      aorta         artery
# 2                       aorta            ascending aorta         artery
# 3             ascending aorta                aortic arch         artery
# 4                 aortic arch           descending aorta         artery
# 5            descending aorta  descending thoracic aorta         artery
# 6   descending thoracic aorta            abdominal aorta         artery
# 7             abdominal aorta              celiac artery         artery
# ...

# %%
node_edge.to_csv('liver-lobule.network_graph.csv')

# %% [markdown]
# # 4. Pancreas' Islet of Langerhans

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] == "dorsal pancreatic artery":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)

# %%
node_edge.to_csv('pancreas-islet_langerhans.network_graph.csv')

# %% [markdown]
# # 5. Spleen's White Pulp

# %%
for i in df_vasculature.index:
    if df_vasculature['UBERON'][i] == "UBERON:0010401":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)

# %%
node_edge.to_csv('spleen-white_pulp.network_graph.csv')

# %% [markdown]
# # 6. Popliteal Lymp Node's Lobule

# %%
for i in df_vasculature.index:
    if df_vasculature['UBERON'][i] == "UBERON:0002250":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)

# %%
node_edge.to_csv('popliteal_lymph_node-lobule.network_graph.csv')

# %% [markdown]
# # 7. Thymus' Lobule

# %%
for i in df_vasculature.index:
    if df_vasculature['UBERON'][i] == "UBERON:0018243":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)

# %%
node_edge.to_csv('thymus-lobule.network_graph.csv')

# %% [markdown]
# # 8. Heart's Sarcomere

# %%
for i in df_vasculature.index:
    if df_vasculature['UBERON'][i] == "UBERON:0001626":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)

# %%
node_edge.to_csv('heart-sarcomere.network_graph.csv')

# %% [markdown]
# # 9. Left Lung - Bronchi

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] == "superior left bronchial artery":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)
# Out:
# ['left ventricle', 'aorta', 'ascending aorta', 'aortic arch', 'descending aorta', 'descending thoracic aorta', 'superior left bronchial artery']

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()
# Out:
# Empty DataFrame
# Columns: [BranchesFrom, Vessel, VesselType, BodyPart, Sex, Anastomoses, ForBranchesSee, MergedVessel, CoordX, CoordY, BranchSequence, CellType, CellTypeLabel, CellTypeID, Biomarkers, BiomarkersLabel, BiomarkersID, ReferenceURL, Reference, ReferenceDOI, UBERON, FMA, BodyPartUberon, UBERONLabel, FMALabel, PathFromHeart, BothTable]
# Index: []
#
# [0 rows x 27 columns]

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)
# Out:
#                 BranchesFrom                          Vessel     VesselType  \
# 0             left ventricle                  left ventricle  heart chamber
# 1             left ventricle                           aorta         artery
# 2                      aorta                 ascending aorta         artery
# 3            ascending aorta                     aortic arch         artery
# 4                aortic arch                descending aorta         artery
# 5           descending aorta       descending thoracic aorta         artery
# 6  descending thoracic aorta  superior left bronchial artery         artery
#
#                            BodyPart  Sex  Anastomoses  ForBranchesSee  \
# 0                     heart chamber  NaN          NaN             NaN
# 1  abdominal cavity;thoracic cavity  NaN          NaN             NaN
# 2                   thoracic cavity  NaN          NaN             NaN
# 3                   thoracic cavity  NaN          NaN             NaN
# ...

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)
# Out:
#                 BranchesFrom                          Vessel     VesselType  \
# 0             left ventricle                  left ventricle  heart chamber
# 1             left ventricle                           aorta         artery
# 2                      aorta                 ascending aorta         artery
# 3            ascending aorta                     aortic arch         artery
# 4                aortic arch                descending aorta         artery
# 5           descending aorta       descending thoracic aorta         artery
# 6  descending thoracic aorta  superior left bronchial artery         artery
#
#                            BodyPart  Sex  Anastomoses  ForBranchesSee  \
# 0                     heart chamber  NaN          NaN             NaN
# 1  abdominal cavity;thoracic cavity  NaN          NaN             NaN
# 2                   thoracic cavity  NaN          NaN             NaN
# 3                   thoracic cavity  NaN          NaN             NaN
# ...

# %%
node_edge.to_csv('lung-left_superior_lobar_bronchus.network_graph.csv')

# %% [markdown]
# # 10. Kidney - Nephron Tubule

# %%
for i in df_vasculature.index:
    if df_vasculature['UBERON'][i] == "UBERON:0001626":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)

# %%
node_edge.to_csv('kidney-nephron_tubule.network_graph.csv')

# %% [markdown]
# # 11. Kidney - Renal Corpuscle

# %%
for i in df_vasculature.index:
    if df_vasculature['UBERON'][i] == "UBERON:0001626":
        pathfh = df_vasculature['PathFromHeart'][i]
node_list = pathfh.split(";")
print(node_list)

# %%
node_edge = pd.DataFrame(columns=['BranchesFrom', 'Vessel', 'VesselType', 'BodyPart', 'Sex', 'Anastomoses', 'ForBranchesSee', 'MergedVessel', 'CoordX', 'CoordY', 'BranchSequence', 'CellType', 'CellTypeLabel', 'CellTypeID', 'Biomarkers', 'BiomarkersLabel', 'BiomarkersID', 'ReferenceURL', 'Reference', 'ReferenceDOI', 'UBERON', 'FMA', 'BodyPartUberon', 'UBERONLabel', 'FMALabel', 'PathFromHeart','BothTable'])
node_edge.head()

# %%
for i in df_vasculature.index:
    if df_vasculature['Vessel'][i] in node_list:
        node_edge.loc[len(node_edge.index)] = df_vasculature.loc[i]
print(node_edge)

# %%
df_matching = pd.read_csv('AS_matching_all.csv')
list_matching = list(df_matching['ID'])
for i in node_edge.index:
    if node_edge['UBERON'][i] in list_matching:
        #print(node_edge['Vessel'])
        node_edge['BothTable'][i] = 1
    else: node_edge['BothTable'][i] = 0
print(node_edge)

# %%
node_edge.to_csv('kidney-renal_corpuscle.network_graph.csv')
